# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
year=[1980,1990,2000,2010,2020]
pop=[12,19,26,31,44]

# %%
sns.scatterplot(x=year,y=pop)
plt.show()

# %%
gender=['male','female','female','male','male','male','female','male']

# %%
sns.countplot(x=gender)
plt.show()

# %%
import pandas as pd
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e9825656-0929-4177-a624-c2a7220e4290" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9825656-0929-4177-a624-c2a7220e4290">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tips.csv to tips.csv

# %%
df=pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
hue_color={'Yes':'Black','No':'Red'}
sns.scatterplot(x='total_bill',y='tip',hue='smoker',hue_order=('Yes','No'),palette=hue_color,data=df)
plt.plot()
# Out:
# []

# %%
sns.countplot(x='smoker',hue='sex',data=df)
plt.show()
