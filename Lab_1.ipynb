# %% [markdown]
# AIM: Review of Arithmetic, Logical operators and Data types in Python

# %%
str1='akash'
str2='hello'
print(str1==str2)
# Out:
# False

# %%
print(str1 is str2)
# Out:
# False

# %%
str3='akash'

# %%
print(id(str1))
print(id(str3))
# Out:
# 140122246651760
# 140122246651760

# %%
print(id(str1)==id(str3))
# Out:
# True

# %%
print(str1 is str3)
# Out:
# True

# %%
print(str1==str3)
# Out:
# True
