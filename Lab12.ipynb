# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-241476da-f6fb-4dc4-9df8-2a78d7d1533a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-241476da-f6fb-4dc4-9df8-2a78d7d1533a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving weather.csv to weather.csv

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded['weather.csv']))

# %%
df.head()
# Out:
#    Month  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0    Jan      8.0     24.3       0.0          3.4       6.3             30
# 1    Feb     14.0     26.9       3.6          4.4       9.7             39
# 2  march     13.7     23.4       3.6          5.8       3.3             85
# 3    Mar     13.3     15.5      39.8          7.2       9.1             54
# 4    Apr      7.6     16.1       2.8          5.6      10.6             50
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0             6            20           68           29       1019.7
# 1             4            17           80           36       1012.4
# 2             6             6           82           69       1009.5
# 3            30            24           62           56       1005.5
# 4            20            28           68           49       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RISK_MM
# ...

# %%
fig,ax=plt.subplots()
ax.plot(df['Month'],df['MinTemp'],color='r',marker='o',label='Min Temp')
ax.plot(df['Month'],df['MaxTemp'],color='b',marker='v',label='Max Temp')
ax.set_xlabel('Month')
ax.set_ylabel('Values of Temperature')
ax.set_title('Temperature vs Month')
ax.legend()
ax.annotate('Min in Max Temp',xy=['Mar',16])
ax.annotate('Max in Min Temp',xy=['Mar',13])
fig.set_size_inches([10,5])
plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(df['Month'],df['MinTemp'],color='r',marker='o',label='Min Temp')
ax.plot(df['Month'],df['MaxTemp'],color='b',marker='v',label='Max Temp')
ax.set_xlabel('Month')
ax.set_ylabel('Values of Temperature')
ax.set_title('Temperature vs Month')
ax.legend()
ax.annotate('Min in Max Temp',xy=['Mar',16],xytext=['Mar',18])
ax.annotate('Max in Min Temp',xy=['Mar',13],xytext=['Apr',11])
fig.set_size_inches([10,5])
plt.show()

# %%
fig,ax=plt.subplots()
ax.plot(df['Month'],df['MinTemp'],color='r',marker='o',label='Min Temp')
ax.plot(df['Month'],df['MaxTemp'],color='b',marker='v',label='Max Temp')
ax.set_xlabel('Month')
ax.set_ylabel('Values of Temperature')
ax.set_title('Temperature vs Month')
ax.legend()
ax.annotate('Min in Max Temp',xy=['Mar',16],xytext=['Mar',18],arrowprops={'arrowstyle':'fancy','color':'cyan'})
ax.annotate('Max in Min Temp',xy=['Mar',13],xytext=['Apr',11],arrowprops={'arrowstyle':'->','color':'seagreen'})
fig.set_size_inches([10,5])
plt.show()
